# %%
import game_2048
import pygame

import numpy as np
import random
#import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


env =game_2048.GAME()

tf.reset_default_graph() # what does it really do?


#These lines establish the feed-forward part of the network used to choose actions
inputs1 = tf.placeholder(shape=[1,16],dtype=tf.float32) 

W = tf.Variable(tf.random_uniform([16,4],0,0.01))

Qout = tf.matmul(inputs1,W)

predict = tf.argmax(Qout,1)

#Below we obtain the loss by taking the sum of squares difference between the target and prediction Q values.
nextQ = tf.placeholder(shape=[1,4],dtype=tf.float32)
loss = tf.reduce_sum(tf.square(nextQ - Qout))
trainer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
updateModel = trainer.minimize(loss)

init = tf.initialize_all_variables()

s = env.reset()
s # state at the begining - since this game has a number the state it is 0
#0, Left,1 Down, 2 Right, 3 Up
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:tensorflow:From C:\Users\Sudhish Kumar\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Initialized GAME()
# Created GAME_BOX of w:360 X h:360
# Created SCORE_BOARD of w:360 X h:60.0
# WARNING:tensorflow:From C:\Users\Sudhish Kumar\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\util\tf_should_use.py:235: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# 1

# %% [markdown]
# print(s)

# %% [markdown]
# s1,r,d,v=env.step(1)
# print("state(position by index goes upto 16)={}\nreward={}\ndead={}\nval(Probability?)={}".format(s1,r,d,v))
# print("-"*50)

# %% [markdown]
# a=3
# s1,r,d,v=env.step(a)
# print("state(position by index goes upto 16)={}\nreward={}\ndead={}\nval(Probability?)={}".format(s1,r,d,v))
# print("-"*50)

# %% [markdown]
# env.game_state

# %% [markdown]
# pygame.display.update()

# %% [markdown]
# env.step(2)

# %% [markdown]
# env.render()

# %%
# Set learning parameters
y = .99   # Gamma almost 1.0 - what does this mean? [0,1]
# higher gammma indicates the decision which gives the best reward is given bias (0.99 vs 0.99^2 (for next move and so on))
e = 0.1   # epsilon value - How many times you want to use the predicted (learning NN) than a random input. 1 will mean never use a predicted value. 0 will mean always use the predicted value
# epsilon - selection of random.
num_episodes = 20 # a large number to stop runaway session (game)
#create lists to contain total rewards and steps per episode
jList = []  # steps in a particular game. i.e. while the game is running how many steps it went through.
rList = []  # reward list - keeping record of rewards on each episode 
with tf.Session() as sess:
    sess.run(init) # call the init function to initialize tensorflow variables.
    for i in range(num_episodes):
        #Reset environment and get first new observation
        s = env.reset() # start a new game (game.refresh()) s should return state number integer e.g. 0
        rAll = 0        # reward All?
        d = False       # dead is False when it is running
        j = 0          # step counter
        #The Q-Network
        while env.running:
            pygame.event.pump()
            env.check_game_status()
            j+=1
            #Choose an action by greedily (with e chance of random action) from the Q-network
            a,allQ = sess.run([predict,Qout],feed_dict={inputs1:np.identity(16)[s:s+1]})
            if np.random.rand(1) < e:
                a[0] = env.action_space_sample() # random movement from the game action space based on epsilon value
            #Get new state and reward from environment
            # env.step returns new state of the game, reward value (since minimization problem it could be 1/score)
            s1,r,d,_ = env.step(a[0]) # same as game.move(a) where a should be  randrange(4)
            pygame.display.update()
            #Obtain the Q' values by feeding the new state through our network
            Q1 = sess.run(Qout,feed_dict={inputs1:np.identity(16)[s1:s1+1]}) # get the next Q table Q(s1,a)
            #Obtain maxQ' and set our target value for chosen action.
            maxQ1 = np.max(Q1) # get the max Q-table value. for this random action 
            targetQ = allQ # target Q table - is zero at the begining of the run.
            targetQ[0,a[0]] = r + y*maxQ1 # equation 1. storing long-term target memory for all the actons done till now.
            #Train our network using target and predicted Q values
            _,W1 = sess.run([updateModel,W],feed_dict={inputs1:np.identity(16)[s:s+1],nextQ:targetQ}) # get the weights ignoring other outputs.
            rAll = max(rAll,r) # total long-term reward. this means we will never reach zero.
            print("Episode {}, reward value rAll = {}\nIs Game dead? {}".format(i,rAll,d))
            s = s1 
            if d == True:
                print(env.game_state)
                #print("Episode {} died after {} steps".format(i,j))
                #Reduce chance of random action as we train the model.
                e = 1./((i/50) + 10)
                break
            
        print("{}\nEpisode {}\n Number of Moves = {}\n Maximum reward achieved={}".format("-"*50,i,j,rAll))
        print(env.game_state)
        jList.append(j)
        rList.append(rAll)
        
num_success=len([v for v in rList if v == 1])
print("Percent of succesful episodes: {}%".format(sum(rList)/num_episodes))

plt.plot(rList)
# Out:
# Episode 0, reward value rAll = 2
# Is Game dead? False
# Episode 0, reward value rAll = 4
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 8
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 32
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 64
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# Episode 0, reward value rAll = 128
# Is Game dead? False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6b91cd76dc0a> in <module>
#      26             #Get new state and reward from environment
#      27             # env.step returns new state of the game, reward value (since minimization problem it could be 1/score)
# ---> 28             s1,r,d,_ = env.step(a[0]) # same as game.move(a) where a should be  randrange(4)
#      29             pygame.display.update()
#      30             #Obtain the Q' values by feeding the new state through our network
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in step(self, action)
#     270             self.move_down()
#     271         elif action==3:
# --> 272             self.move_up()
#     273
#     274
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in move_up(self)
#     384
#     385     def move_up(self):
# --> 386         self.collect_up()
#     387         if self.need_random_tile:
#     388             self.add_random_tile()
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in collect_up(self)
#     505                     continue
#     506             col+=1
# --> 507             self.update_view()
#     508
#     509
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in update_view(self)
#     318         for row in range(NUMBER_OF_TILE):
#     319             for col in range(NUMBER_OF_TILE):
# --> 320                 self.tile_group.add(row,col,self.game_state[row,col])
#     321         self.tile_group.draw(self.screen)
#     322         self.score_board.update_score()
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in add(self, row, col, value)
#     209
#     210     def add(self, row,col,value):
# --> 211         tile=TILE(row,col,value)
#     212         super(pygame.sprite.Group,self).add(tile)
#     213
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in __init__(self, r, c, v)
#      72
#      73         self.image = pygame.Surface([self.tile_w, self.tile_h])
# ---> 74         self.update_value()
#      75         self.rect = self.image.get_rect()
#      76         self.rect.x=BOX_ORIGIN_x+TILE_GAP+self.col*(TILE_SIZE+TILE_GAP)
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in update_value(self)
#      78
#      79     def update_value(self):
# ---> 80         self.get_value()
#      81         self.image.fill(self.color)
#      82         self.image.blit(self.valueImage,((self.tile_w-self.valueImage.get_width())/2,(self.tile_h-self.fontSize)/2))
#
# ~\Documents\GitHub\javascript\busywithcoding\square_2048\game_2048.py in get_value(self)
#      88             pygame.font.init()
#      89
# ---> 90         value_font= pygame.font.SysFont('freesans', self.fontSize)
#      91         if self.value==0:
#      92             value_text=""
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygame\sysfont.py in SysFont(name, size, bold, italic, constructor)
#     360         set_italic = True
#     361
# --> 362     return constructor(fontname, size, set_bold, set_italic)
#     363
#     364
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygame\sysfont.py in font_constructor(fontpath, size, bold, italic)
#     283     import pygame.font
#     284
# --> 285     font = pygame.font.Font(fontpath, size)
#     286     if bold:
#     287         font.set_bold(1)
#
# KeyboardInterrupt:

# %%
plt.plot(jList)

# %%
sum(rList)

# %%
plt.plot(jList,rList,'.')
